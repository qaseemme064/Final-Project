# %%
import pandas as pd
import json

# %%
file_to_load1 = '../Resource/dataset/json/p01/exercise.json'
file_to_load2 = '../Resource/dataset/json/p01/resting_heart_rate.json'
file_to_load3 = '../Resource/dataset/json/p01/sleep.json'

file_to_load4 = '../Resource/dataset/json/p02/exercise.json'
file_to_load5 = '../Resource/dataset/json/p02/resting_heart_rate.json'
file_to_load6 = '../Resource/dataset/json/p02/sleep.json'

file_to_load7 = '../Resource/dataset/json/p03/exercise.json'
file_to_load8 = '../Resource/dataset/json/p03/resting_heart_rate.json'
file_to_load9 = '../Resource/dataset/json/p03/sleep.json'

file_to_load10 = '../Resource/dataset/json/p04/exercise.json'
file_to_load11 = '../Resource/dataset/json/p04/resting_heart_rate.json'
file_to_load12 = '../Resource/dataset/json/p04/sleep.json'

file_to_load13 = '../Resource/dataset/json/p05/exercise.json'
file_to_load14 = '../Resource/dataset/json/p05/resting_heart_rate.json'
file_to_load15 = '../Resource/dataset/json/p05/sleep.json'

file_to_load16 = '../Resource/dataset/json/p06/exercise.json'
file_to_load17 = '../Resource/dataset/json/p06/resting_heart_rate.json'
file_to_load18 = '../Resource/dataset/json/p06/sleep.json'

file_to_load19 = '../Resource/dataset/json/p07/exercise.json'
file_to_load20 = '../Resource/dataset/json/p07/resting_heart_rate.json'
file_to_load21 = '../Resource/dataset/json/p07/sleep.json'

file_to_load22 = '../Resource/dataset/json/p08/exercise.json'
file_to_load23 = '../Resource/dataset/json/p08/resting_heart_rate.json'
file_to_load24 = '../Resource/dataset/json/p08/sleep.json'

file_to_load25 = '../Resource/dataset/json/p09/exercise.json'
file_to_load26 = '../Resource/dataset/json/p09/resting_heart_rate.json'
file_to_load27 = '../Resource/dataset/json/p09/sleep.json'

file_to_load28 = '../Resource/dataset/json/p10/exercise.json'
file_to_load29 = '../Resource/dataset/json/p10/resting_heart_rate.json'
file_to_load30 = '../Resource/dataset/json/p10/sleep.json'

file_to_load31 = '../Resource/dataset/json/p11/exercise.json'
file_to_load32 = '../Resource/dataset/json/p11/resting_heart_rate.json'
file_to_load33 = '../Resource/dataset/json/p11/sleep.json'

file_to_load34 = '../Resource/dataset/json/p12/exercise.json'
#file_to_load35 = '../Resource/dataset/json/p12/resting_heart_rate.json'
file_to_load36 = '../Resource/dataset/json/p12/sleep.json'

file_to_load37 = '../Resource/dataset/json/p13/exercise.json'
#file_to_load38 = '../Resource/dataset/json/p13/resting_heart_rate.json'
file_to_load39 = '../Resource/dataset/json/p13/sleep.json'

file_to_load40 = '../Resource/dataset/json/p14/exercise.json'
file_to_load41 = '../Resource/dataset/json/p14/resting_heart_rate.json'
file_to_load42 = '../Resource/dataset/json/p14/sleep.json'

file_to_load43 = '../Resource/dataset/json/p15/exercise.json'
file_to_load44 = '../Resource/dataset/json/p15/resting_heart_rate.json'
file_to_load45 = '../Resource/dataset/json/p15/sleep.json'

file_to_load46 = '../Resource/dataset/json/p16/exercise.json'
file_to_load47 = '../Resource/dataset/json/p16/resting_heart_rate.json'
file_to_load48 = '../Resource/dataset/json/p16/sleep.json'
file_to_load49 = '../Resource/dataset/json/p16/distance.json'

# %%
df1= pd.read_json(file_to_load1)
df2= pd.read_json(file_to_load2)
df3= pd.read_json(file_to_load3)
df4= pd.read_json(file_to_load4)
df5= pd.read_json(file_to_load5)
df6= pd.read_json(file_to_load6)
df7= pd.read_json(file_to_load7)
df8= pd.read_json(file_to_load8)
df9= pd.read_json(file_to_load9)
df10= pd.read_json(file_to_load10)
df11= pd.read_json(file_to_load11)
df12= pd.read_json(file_to_load12)
df13= pd.read_json(file_to_load13)
df14= pd.read_json(file_to_load14)
df15= pd.read_json(file_to_load15)
df16= pd.read_json(file_to_load16)
df17= pd.read_json(file_to_load17)
df18= pd.read_json(file_to_load18)
df19= pd.read_json(file_to_load19)
df20= pd.read_json(file_to_load20)
df21= pd.read_json(file_to_load21)
df22= pd.read_json(file_to_load22)
df23= pd.read_json(file_to_load23)
df24= pd.read_json(file_to_load24)
df25= pd.read_json(file_to_load25)
df26= pd.read_json(file_to_load26)
df27= pd.read_json(file_to_load27)
df28= pd.read_json(file_to_load28)
df29= pd.read_json(file_to_load29)
df30= pd.read_json(file_to_load30)
df31= pd.read_json(file_to_load31)
df32= pd.read_json(file_to_load32)
df33= pd.read_json(file_to_load33)
df34= pd.read_json(file_to_load34)
#df35= pd.read_json(file_to_load35)
df36= pd.read_json(file_to_load36)
df37= pd.read_json(file_to_load37)
#df38= pd.read_json(file_to_load38)
df39= pd.read_json(file_to_load39)
df40= pd.read_json(file_to_load40)
df41= pd.read_json(file_to_load41)
df42= pd.read_json(file_to_load42)
df43= pd.read_json(file_to_load43)
df44= pd.read_json(file_to_load44)
df45= pd.read_json(file_to_load45)
df46= pd.read_json(file_to_load46)
df47= pd.read_json(file_to_load47)
df48= pd.read_json(file_to_load48)
df49= pd.read_json(file_to_load49)

# %%
df1.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p01/exercise.csv' , index=False)
df2.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p01/resting_heart_rate.csv' , index=False)
df3.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p01/sleep.csv' , index=False)

df4.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p02/exercise.csv' , index=False)
df5.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p02/resting_heart_rate.csv' , index=False)
df6.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p02/sleep.csv' , index=False)

df7.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p03/exercise.csv' , index=False)
df8.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p03/resting_heart_rate.csv' , index=False)
df9.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p03/sleep.csv' , index=False)

df10.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p04/exercise.csv' , index=False)
df11.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p04/resting_heart_rate.csv' , index=False)
df12.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p04/sleep.csv' , index=False)

df13.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p05/exercise.csv' , index=False)
df14.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p05/resting_heart_rate.csv' , index=False)
df15.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p05/sleep.csv' , index=False)

df16.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p06/exercise.csv' , index=False)
df17.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p06/resting_heart_rate.csv' , index=False)
df18.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p06/sleep.csv' , index=False)

df19.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p07/exercise.csv' , index=False)
df20.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p07/resting_heart_rate.csv' , index=False)
df21.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p07/sleep.csv' , index=False)

df22.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p08/exercise.csv' , index=False)
df23.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p08/resting_heart_rate.csv' , index=False)
df24.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p08/sleep.csv' , index=False)

df25.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p09/exercise.csv' , index=False)
df26.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p09/resting_heart_rate.csv' , index=False)
df27.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p09/sleep.csv' , index=False)

df28.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p10/exercise.csv' , index=False)
df29.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p10/resting_heart_rate.csv' , index=False)
df30.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p10/sleep.csv' , index=False)

df31.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p11/exercise.csv' , index=False)
df32.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p11/resting_heart_rate.csv' , index=False)
df33.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p11/sleep.csv' , index=False)

df34.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p12/exercise.csv' , index=False)
#df35.to_csv(r'Resource/dataset/csv/not_cleaned_csv/p12/resting_heart_rate.csv' , index=False)
df36.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p12/sleep.csv' , index=False)

df37.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p13/exercise.csv' , index=False)
#df38.to_csv(r'Resource/dataset/csv/not_cleaned_csv/p13/resting_heart_rate.csv' , index=False)
df39.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p13/sleep.csv' , index=False)

df40.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p14/exercise.csv' , index=False)
df41.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p14/resting_heart_rate.csv' , index=False)
df42.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p14/sleep.csv' , index=False)

df43.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p15/exercise.csv' , index=False)
df44.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p15/resting_heart_rate.csv' , index=False)
df45.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p15/sleep.csv' , index=False)

df46.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p16/exercise.csv' , index=False)
df47.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p16/resting_heart_rate.csv' , index=False)
df48.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p16/sleep.csv' , index=False)
df49.to_csv(r'../Resource/dataset/csv/not_cleaned_csv/p16/distance.csv' , index=False)
